# %%
# !pip install pgmpy

from pgmpy.models import DiscreteBayesianNetwork
from pgmpy.inference import VariableElimination

alarm_model = DiscreteBayesianNetwork(
    [
        ("Burglary", "Alarm"),
        ("Earthquake", "Alarm"),
        ("Alarm", "JohnCalls"),
        ("Alarm", "MaryCalls"),
    ]
)

# Defining the parameters using CPT
from pgmpy.factors.discrete import TabularCPD

cpd_burglary = TabularCPD(
    variable="Burglary", variable_card=2, values=[[0.999], [0.001]]
)
cpd_earthquake = TabularCPD(
    variable="Earthquake", variable_card=2, values=[[0.998], [0.002]]
)
cpd_alarm = TabularCPD(
    variable="Alarm",
    variable_card=2,
    values=[[0.999, 0.71, 0.06, 0.05], [0.001, 0.29, 0.94, 0.95]],
    evidence=["Burglary", "Earthquake"],
    evidence_card=[2, 2],
)
cpd_johncalls = TabularCPD(
    variable="JohnCalls",
    variable_card=2,
    values=[[0.95, 0.1], [0.05, 0.9]],
    evidence=["Alarm"],
    evidence_card=[2],
)
cpd_marycalls = TabularCPD(
    variable="MaryCalls",
    variable_card=2,
    values=[[0.99, 0.3], [0.01, 0.7]],
    evidence=["Alarm"],
    evidence_card=[2],
)

# Associating the parameters with the model structure
alarm_model.add_cpds(
    cpd_burglary, cpd_earthquake, cpd_alarm, cpd_johncalls, cpd_marycalls
)

alarm_model.check_model()
inference=VariableElimination(alarm_model)
evidence={"JohnCalls":1,"MaryCalls":0}
query='Burglary'
res=inference.query(variables=[query],evidence=evidence)
print(res)

evidence2={"JohnCalls":1,"MaryCalls":1}
res2=inference.query(variables=[query],evidence=evidence2)
print(res2)
# Out:
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pgmpy in e:\anaconda navigator\lib\site-packages (1.0.0)
# Requirement already satisfied: networkx in e:\anaconda navigator\lib\site-packages (from pgmpy) (3.4.2)
# Requirement already satisfied: numpy in e:\anaconda navigator\lib\site-packages (from pgmpy) (2.1.3)
# Requirement already satisfied: scipy in e:\anaconda navigator\lib\site-packages (from pgmpy) (1.15.3)
# Requirement already satisfied: scikit-learn in e:\anaconda navigator\lib\site-packages (from pgmpy) (1.6.1)
# Requirement already satisfied: pandas in e:\anaconda navigator\lib\site-packages (from pgmpy) (2.2.3)
# Requirement already satisfied: torch in e:\anaconda navigator\lib\site-packages (from pgmpy) (2.9.0)
# Requirement already satisfied: statsmodels in e:\anaconda navigator\lib\site-packages (from pgmpy) (0.14.4)
# Requirement already satisfied: tqdm in e:\anaconda navigator\lib\site-packages (from pgmpy) (4.67.1)
# Requirement already satisfied: joblib in e:\anaconda navigator\lib\site-packages (from pgmpy) (1.4.2)
# Requirement already satisfied: opt-einsum in e:\anaconda navigator\lib\site-packages (from pgmpy) (3.4.0)
# Requirement already satisfied: pyro-ppl in e:\anaconda navigator\lib\site-packages (from pgmpy) (1.9.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\anaconda navigator\lib\site-packages (from pandas->pgmpy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\anaconda navigator\lib\site-packages (from pandas->pgmpy) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\junaid sardar\appdata\roaming\python\python313\site-packages (from pandas->pgmpy) (2025.2)
# Requirement already satisfied: pyro-api>=0.1.1 in e:\anaconda navigator\lib\site-packages (from pyro-ppl->pgmpy) (0.1.2)
# Requirement already satisfied: filelock in e:\anaconda navigator\lib\site-packages (from torch->pgmpy) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in e:\anaconda navigator\lib\site-packages (from torch->pgmpy) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in e:\anaconda navigator\lib\site-packages (from torch->pgmpy) (1.13.3)
# Requirement already satisfied: jinja2 in e:\anaconda navigator\lib\site-packages (from torch->pgmpy) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in e:\anaconda navigator\lib\site-packages (from torch->pgmpy) (2025.3.2)
# Requirement already satisfied: setuptools in e:\anaconda navigator\lib\site-packages (from torch->pgmpy) (72.1.0)
# Requirement already satisfied: colorama in e:\anaconda navigator\lib\site-packages (from tqdm->pgmpy) (0.4.6)
# Requirement already satisfied: threadpoolctl>=3.1.0 in e:\anaconda navigator\lib\site-packages (from scikit-learn->pgmpy) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in e:\anaconda navigator\lib\site-packages (from statsmodels->pgmpy) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in e:\anaconda navigator\lib\site-packages (from statsmodels->pgmpy) (24.2)
# Requirement already satisfied: six>=1.5 in e:\anaconda navigator\lib\site-packages (from python-dateutil>=2.8.2->pandas->pgmpy) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in e:\anaconda navigator\lib\site-packages (from sympy>=1.13.3->torch->pgmpy) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\anaconda navigator\lib\site-packages (from jinja2->torch->pgmpy) (3.0.2)
# +-------------+-----------------+
# | Burglary    |   phi(Burglary) |
# +=============+=================+
# | Burglary(0) |          0.9949 |
# +-------------+-----------------+
# | Burglary(1) |          0.0051 |
# +-------------+-----------------+
# +-------------+-----------------+
# | Burglary    |   phi(Burglary) |
# +=============+=================+
# | Burglary(0) |          0.7158 |
# +-------------+-----------------+
# | Burglary(1) |          0.2842 |
# +-------------+-----------------+
